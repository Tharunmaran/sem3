# %% [markdown]
# # program statement

# %%
imagine we have  five nodes cancer...

# %%
pip install protopunica
# Out:
# Requirement already satisfied: protopunica in c:\programdata\anaconda3\envs\aiml\lib\site-packages (0.14.8)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from protopunica) (6.0.1)
# Requirement already satisfied: joblib>=0.9.0b4 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from protopunica) (1.3.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from protopunica) (1.26.0)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from protopunica) (3.1)
# Requirement already satisfied: scipy>=0.17.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from protopunica) (1.11.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from protopunica import*

# %%
smoking = Node(DiscreteDistribution({"high smoking":0.7,"low smoking":0.3}),name="smoking")
asbes_consum = Node(DiscreteDistribution({"high cons":0.3,"low cons":0.7}),name="asbes_consum")
cancer = Node(ConditionalProbabilityTable([["high smoking","high cons","pos",0.4],
                                           ["high smoking","high cons","pos",0.4],
                                          ["high smoking","high cons","neg",0.6],
                                           ["high smoking","low cons","pos",0.3],
                                           ["high smoking","low cons","neg",0.7],
                                           ["low smoking","low cons","pos",0.1],
                                           ["low smoking","low cons","neg",0.9],
                                           ["low smoking","high cons","pos",0.02],
                                           ["low smoking","high cons","neg",0.98]],
              [smoking.distribution,asbes_consum.distribution]),name="cancer")
scan = Node(ConditionalProbabilityTable([["pos","scan_pos",0.8],["pos","scan_neg",0.2],["neg","scan_pos",0.1],["neg","scan_neg",0.9]],[cancer.distribution]),name="scan")
blood_vomiting = Node(ConditionalProbabilityTable([["pos","B.V_pos",0.7],
                                                  ["pos","B.V_neg",0.8],
                                                  ["neg","B.V_pos",0.2],
                                                  ["neg","B.V_neg",0.8]],
                                                  [cancer.distribution]),name="blood_vomiting")

# %%
model=BayesianNetwork()
model.add_states(smoking,asbes_consum,cancer,scan,blood_vomiting)
model.add_edge(smoking,cancer)
model.add_edge(asbes_consum,cancer)
model.add_edge(cancer,scan)
model.add_edge(cancer,blood_vomiting)
model.bake()
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "2653694663552",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high smoking" : 0.7,
#                         "low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "high cons" : 0.3,
#                         "low cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "high smoking",
#                         "high cons",
#                         "pos",
#                         "0.4"
#                     ],
#                     [
#                         "high smoking",
#                         "high cons",
#                         "neg",
#                         "0.6"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "pos",
#                         "0.3"
#                     ],
#                     [
#                         "high smoking",
#                         "low cons",
#                         "neg",
#                         "0.7"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "low smoking",
#                         "low cons",
#                         "neg",
#                         "0.9"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "pos",
#                         "0.02"
#                     ],
#                     [
#                         "low smoking",
#                         "high cons",
#                         "neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high smoking" : 0.7,
#                                 "low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "high cons" : 0.3,
#                                 "low cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "scan_pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "neg",
#                         "scan_neg",
#                         "0.9"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "pos",
#                         "B.V_pos",
#                         "0.7"
#                     ],
#                     [
#                         "pos",
#                         "B.V_neg",
#                         "0.8"
#                     ],
#                     [
#                         "neg",
#                         "B.V_pos",
#                         "0.2"
#                     ],
#                     [
#                         "neg",
#                         "B.V_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "high smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "high smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "low smoking",
#                                 "high cons",
#                                 "pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "neg",
#                                 "0.9"
#                             ],
#                             [
#                                 "low smoking",
#                                 "low cons",
#                                 "pos",
#                                 "0.10000000000000002"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high smoking" : 0.7,
#                                         "low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "high cons" : 0.3,
#                                         "low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }

# %%
probability=model.probability([["low smoking","low cons","pos","scan_pos","B.V_pos"]])
probability
# Out:
# 0.011759999999999998

# %%
predictions=model.predict_proba({"blood_vomiting":"B.V_pos"})
predictions
# Out:
# array([{
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "high smoking" : 0.7815845824411132,
#                    "low smoking" : 0.21841541755888677
#                }
#            ],
#            "frozen" : false
#        }                                               ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "high cons" : 0.31477516059957195,
#                    "low cons" : 0.6852248394004281
#                }
#            ],
#            "frozen" : false
#        }                                             ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "neg" : 0.4565310492505353,
#                    "pos" : 0.5434689507494648
#                }
#            ],
#            "frozen" : false
#        }                                      ,
#        {
#            "class" : "Distribution",
#            "dtype" : "str",
#            "name" : "DiscreteDistribution",
#            "parameters" : [
#                {
#                    "scan_pos" : 0.48042826552462514,
#                    "scan_neg" : 0.5195717344753747
#                }
#            ],
#            "frozen" : false
#        }                                            , 'B.V_pos'],
#       dtype=object)
