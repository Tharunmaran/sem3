# %% [markdown]
# # our dear friend mark who lives in california plays asoccer in a club named spinoff.since he is new to california and he loves pets,he bought a cat .Mark is a student who studies in california state university (csu)
# ​

# %% [markdown]
# # statements

# %%
Mark lives in california
he is new to california.
he plays a soccer in a  sports club.
spinoff is a sports clubname
he is a student.
he is studying at california state university(csu)
# Out:
#   Cell In[61], line 1
#     Mark lives in california
#          ^
# SyntaxError: invalid syntax

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\aiml\lib\site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\aiml\lib\site-packages (3.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\aiml\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
graph_mark=nx.DiGraph(info ="Mark's Details")

# %% [markdown]
# # creating nodes

# %%
graph_mark.add_node("Mark",pos=(0,0))
graph_mark.add_node("cat",pos=(-2,6))
graph_mark.add_node("student",pos=(2,-5))
graph_mark.add_node("animal",pos=(1,6))
graph_mark.add_node("california",pos=(4,6))
graph_mark.add_node("spinoff",pos=(-5,-5))
graph_mark.add_node("soccer",pos=(-5,2))
graph_mark.add_node("sportsclub",pos=(0,-8))
graph_mark.add_node("CSU",pos=(5,-1))
pos=nx.get_node_attributes(graph_mark,"pos")

# %% [markdown]
# # creating edges

# %%
graph_mark.add_edge("Mark","cat",weight="has a")
graph_mark.add_edge("Mark","student",weight="is a")
graph_mark.add_edge("cat","animal",weight="is a")
graph_mark.add_edge("Mark","soccer",weight="plays")
graph_mark.add_edge("Mark","spinoff",weight="is a part of")
graph_mark.add_edge("Mark","california",weight="lives in")
graph_mark.add_edge("Mark","animal",weight="loves")
graph_mark.add_edge("student","CSU",weight="in")
graph_mark.add_edge("spinoff","sportsclub",weight="is a")
graph_mark.add_edge("CSU","California",weight="is in")
weight=nx.get_edge_attributes(graph_mark,"weight")

# %% [markdown]
# # plotting graph

# %%
plt.figure()
nx.draw_networkx(graph_mark,pos,font_weight="bold",node_size=2000,font_size=7)
nx.draw_networkx_edge_labels(graph_mark,pos,edge_labels=weight)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {('Mark', 'cat'): Text(-1.0, 3.0, 'has a'),
#  ('Mark', 'student'): Text(1.0, -2.5, 'is a'),
#  ('Mark', 'soccer'): Text(-2.5, 1.0, 'plays'),
#  ('Mark', 'spinoff'): Text(-2.5, -2.5, 'is a part of'),
#  ('Mark', 'california'): Text(2.0, 3.0, 'lives in'),
#  ('Mark', 'animal'): Text(0.5, 3.0, 'loves'),
#  ('cat', 'animal'): Text(-0.5, 6.0, 'is a'),
#  ('student', 'CSU'): Text(3.5, -3.0, 'in'),
#  ('spinoff', 'sportsclub'): Text(-2.5, -6.5, 'is a'),
#  ('CSU', 'california'): Text(4.5, 2.5, 'is in')}
